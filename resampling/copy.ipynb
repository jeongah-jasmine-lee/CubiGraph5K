# %%
import os
import shutil
from pathlib import Path

# 경로 세팅
result_txt_path = "./resampling-result.txt"  # 텍스트 파일 경로
src_root = "../cubicasa5k-662"
dst_root = "../cubicasa5k-114"

os.makedirs(dst_root, exist_ok=True)

# 1. txt 파일에서 Easy/Medium 경로 파싱
selected_dirs = []

with open(result_txt_path, 'r') as f:
    for line in f:
        line = line.strip()
        if line.startswith("[Easy]") or line.startswith("[Medium]"):
            # 예: "[Easy] ../cubicasa5k-666/high_quality/641 (score: 0.2099)"
            path_part = line.split(']')[1].strip().split(" (score")[0].strip()
            selected_dirs.append(path_part)

# 2. 복사 수행
copied = 0
for src_dir in selected_dirs:
    src_dir = os.path.normpath(src_dir)
    src_dir_abs = os.path.abspath(src_dir)

    # 상대 경로 추출
    rel_path = os.path.relpath(src_dir, start=src_root)
    dst_dir = os.path.join(dst_root, rel_path)

    # 복사
    if os.path.exists(src_dir_abs):
        shutil.copytree(src_dir_abs, dst_dir, dirs_exist_ok=True)
        copied += 1
        print(f"Copied from {src_dir_abs} to {dst_dir}")
    else:
        print(f"[❗경고] 원본 폴더 없음: {src_dir_abs}")

print(f"\n✅ 총 {copied}개의 폴더가 '{dst_root}'에 복사 완료되었습니다.")
# Out:
# Copied from /Users/jeongahlee/Documents/github folder/CubiGraph5K/cubicasa5k-662/high_quality/3530 to ../cubicasa5k-114/high_quality/3530
# Copied from /Users/jeongahlee/Documents/github folder/CubiGraph5K/cubicasa5k-662/colorful/4006 to ../cubicasa5k-114/colorful/4006
# Copied from /Users/jeongahlee/Documents/github folder/CubiGraph5K/cubicasa5k-662/high_quality_architectural/233 to ../cubicasa5k-114/high_quality_architectural/233
# Copied from /Users/jeongahlee/Documents/github folder/CubiGraph5K/cubicasa5k-662/high_quality_architectural/14310 to ../cubicasa5k-114/high_quality_architectural/14310
# Copied from /Users/jeongahlee/Documents/github folder/CubiGraph5K/cubicasa5k-662/high_quality/10083 to ../cubicasa5k-114/high_quality/10083
# Copied from /Users/jeongahlee/Documents/github folder/CubiGraph5K/cubicasa5k-662/high_quality/9000 to ../cubicasa5k-114/high_quality/9000
# Copied from /Users/jeongahlee/Documents/github folder/CubiGraph5K/cubicasa5k-662/high_quality_architectural/14311 to ../cubicasa5k-114/high_quality_architectural/14311
# Copied from /Users/jeongahlee/Documents/github folder/CubiGraph5K/cubicasa5k-662/high_quality_architectural/1902 to ../cubicasa5k-114/high_quality_architectural/1902
# Copied from /Users/jeongahlee/Documents/github folder/CubiGraph5K/cubicasa5k-662/high_quality/14127 to ../cubicasa5k-114/high_quality/14127
# Copied from /Users/jeongahlee/Documents/github folder/CubiGraph5K/cubicasa5k-662/high_quality_architectural/14438 to ../cubicasa5k-114/high_quality_architectural/14438
# Copied from /Users/jeongahlee/Documents/github folder/CubiGraph5K/cubicasa5k-662/high_quality_architectural/12677 to ../cubicasa5k-114/high_quality_architectural/12677
# Copied from /Users/jeongahlee/Documents/github folder/CubiGraph5K/cubicasa5k-662/high_quality_architectural/11409 to ../cubicasa5k-114/high_quality_architectural/11409
# Copied from /Users/jeongahlee/Documents/github folder/CubiGraph5K/cubicasa5k-662/high_quality_architectural/9719 to ../cubicasa5k-114/high_quality_architectural/9719
# Copied from /Users/jeongahlee/Documents/github folder/CubiGraph5K/cubicasa5k-662/high_quality_architectural/11061 to ../cubicasa5k-114/high_quality_architectural/11061
# Copied from /Users/jeongahlee/Documents/github folder/CubiGraph5K/cubicasa5k-662/high_quality_architectural/12125 to ../cubicasa5k-114/high_quality_architectural/12125
# Copied from /Users/jeongahlee/Documents/github folder/CubiGraph5K/cubicasa5k-662/high_quality_architectural/8681 to ../cubicasa5k-114/high_quality_architectural/8681
# Copied from /Users/jeongahlee/Documents/github folder/CubiGraph5K/cubicasa5k-662/high_quality_architectural/1838 to ../cubicasa5k-114/high_quality_architectural/1838
# Copied from /Users/jeongahlee/Documents/github folder/CubiGraph5K/cubicasa5k-662/high_quality/11384 to ../cubicasa5k-114/high_quality/11384
# Copied from /Users/jeongahlee/Documents/github folder/CubiGraph5K/cubicasa5k-662/high_quality/9619 to ../cubicasa5k-114/high_quality/9619
# Copied from /Users/jeongahlee/Documents/github folder/CubiGraph5K/cubicasa5k-662/high_quality_architectural/2142 to ../cubicasa5k-114/high_quality_architectural/2142
# Copied from /Users/jeongahlee/Documents/github folder/CubiGraph5K/cubicasa5k-662/high_quality_architectural/11002 to ../cubicasa5k-114/high_quality_architectural/11002
# Copied from /Users/jeongahlee/Documents/github folder/CubiGraph5K/cubicasa5k-662/high_quality_architectural/11016 to ../cubicasa5k-114/high_quality_architectural/11016
# Copied from /Users/jeongahlee/Documents/github folder/CubiGraph5K/cubicasa5k-662/high_quality/13442 to ../cubicasa5k-114/high_quality/13442
# Copied from /Users/jeongahlee/Documents/github folder/CubiGraph5K/cubicasa5k-662/high_quality_architectural/11008 to ../cubicasa5k-114/high_quality_architectural/11008
# Copied from /Users/jeongahlee/Documents/github folder/CubiGraph5K/cubicasa5k-662/high_quality_architectural/20064 to ../cubicasa5k-114/high_quality_architectural/20064
# Copied from /Users/jeongahlee/Documents/github folder/CubiGraph5K/cubicasa5k-662/high_quality/1244 to ../cubicasa5k-114/high_quality/1244
# Copied from /Users/jeongahlee/Documents/github folder/CubiGraph5K/cubicasa5k-662/high_quality_architectural/11409 to ../cubicasa5k-114/high_quality_architectural/11409
# Copied from /Users/jeongahlee/Documents/github folder/CubiGraph5K/cubicasa5k-662/high_quality_architectural/3218 to ../cubicasa5k-114/high_quality_architectural/3218
# Copied from /Users/jeongahlee/Documents/github folder/CubiGraph5K/cubicasa5k-662/high_quality_architectural/12845 to ../cubicasa5k-114/high_quality_architectural/12845
# Copied from /Users/jeongahlee/Documents/github folder/CubiGraph5K/cubicasa5k-662/high_quality_architectural/13450 to ../cubicasa5k-114/high_quality_architectural/13450
# Copied from /Users/jeongahlee/Documents/github folder/CubiGraph5K/cubicasa5k-662/high_quality_architectural/8302 to ../cubicasa5k-114/high_quality_architectural/8302
# Copied from /Users/jeongahlee/Documents/github folder/CubiGraph5K/cubicasa5k-662/high_quality_architectural/12454 to ../cubicasa5k-114/high_quality_architectural/12454
# Copied from /Users/jeongahlee/Documents/github folder/CubiGraph5K/cubicasa5k-662/high_quality_architectural/10728 to ../cubicasa5k-114/high_quality_architectural/10728
# Copied from /Users/jeongahlee/Documents/github folder/CubiGraph5K/cubicasa5k-662/high_quality/1877 to ../cubicasa5k-114/high_quality/1877
# Copied from /Users/jeongahlee/Documents/github folder/CubiGraph5K/cubicasa5k-662/high_quality_architectural/11021 to ../cubicasa5k-114/high_quality_architectural/11021
# Copied from /Users/jeongahlee/Documents/github folder/CubiGraph5K/cubicasa5k-662/high_quality_architectural/11018 to ../cubicasa5k-114/high_quality_architectural/11018
# Copied from /Users/jeongahlee/Documents/github folder/CubiGraph5K/cubicasa5k-662/high_quality_architectural/6464 to ../cubicasa5k-114/high_quality_architectural/6464
# Copied from /Users/jeongahlee/Documents/github folder/CubiGraph5K/cubicasa5k-662/high_quality/13442 to ../cubicasa5k-114/high_quality/13442
# Copied from /Users/jeongahlee/Documents/github folder/CubiGraph5K/cubicasa5k-662/high_quality_architectural/11004 to ../cubicasa5k-114/high_quality_architectural/11004
# Copied from /Users/jeongahlee/Documents/github folder/CubiGraph5K/cubicasa5k-662/high_quality_architectural/11002 to ../cubicasa5k-114/high_quality_architectural/11002
# Copied from /Users/jeongahlee/Documents/github folder/CubiGraph5K/cubicasa5k-662/high_quality_architectural/11008 to ../cubicasa5k-114/high_quality_architectural/11008
# Copied from /Users/jeongahlee/Documents/github folder/CubiGraph5K/cubicasa5k-662/high_quality_architectural/14236 to ../cubicasa5k-114/high_quality_architectural/14236
# Copied from /Users/jeongahlee/Documents/github folder/CubiGraph5K/cubicasa5k-662/colorful/13278 to ../cubicasa5k-114/colorful/13278
# Copied from /Users/jeongahlee/Documents/github folder/CubiGraph5K/cubicasa5k-662/colorful/14937 to ../cubicasa5k-114/colorful/14937
# Copied from /Users/jeongahlee/Documents/github folder/CubiGraph5K/cubicasa5k-662/colorful/1732 to ../cubicasa5k-114/colorful/1732
# Copied from /Users/jeongahlee/Documents/github folder/CubiGraph5K/cubicasa5k-662/colorful/14927 to ../cubicasa5k-114/colorful/14927
# Copied from /Users/jeongahlee/Documents/github folder/CubiGraph5K/cubicasa5k-662/high_quality_architectural/13733 to ../cubicasa5k-114/high_quality_architectural/13733
# Copied from /Users/jeongahlee/Documents/github folder/CubiGraph5K/cubicasa5k-662/high_quality_architectural/1902 to ../cubicasa5k-114/high_quality_architectural/1902
# Copied from /Users/jeongahlee/Documents/github folder/CubiGraph5K/cubicasa5k-662/high_quality_architectural/2030 to ../cubicasa5k-114/high_quality_architectural/2030
# Copied from /Users/jeongahlee/Documents/github folder/CubiGraph5K/cubicasa5k-662/high_quality_architectural/2117 to ../cubicasa5k-114/high_quality_architectural/2117
# Copied from /Users/jeongahlee/Documents/github folder/CubiGraph5K/cubicasa5k-662/high_quality_architectural/239 to ../cubicasa5k-114/high_quality_architectural/239
# Copied from /Users/jeongahlee/Documents/github folder/CubiGraph5K/cubicasa5k-662/colorful/2196 to ../cubicasa5k-114/colorful/2196
# Copied from /Users/jeongahlee/Documents/github folder/CubiGraph5K/cubicasa5k-662/high_quality_architectural/13648 to ../cubicasa5k-114/high_quality_architectural/13648
# Copied from /Users/jeongahlee/Documents/github folder/CubiGraph5K/cubicasa5k-662/high_quality_architectural/47 to ../cubicasa5k-114/high_quality_architectural/47
# Copied from /Users/jeongahlee/Documents/github folder/CubiGraph5K/cubicasa5k-662/high_quality_architectural/3701 to ../cubicasa5k-114/high_quality_architectural/3701
# Copied from /Users/jeongahlee/Documents/github folder/CubiGraph5K/cubicasa5k-662/high_quality_architectural/12573 to ../cubicasa5k-114/high_quality_architectural/12573
# Copied from /Users/jeongahlee/Documents/github folder/CubiGraph5K/cubicasa5k-662/high_quality_architectural/11696 to ../cubicasa5k-114/high_quality_architectural/11696
# Copied from /Users/jeongahlee/Documents/github folder/CubiGraph5K/cubicasa5k-662/high_quality/11317 to ../cubicasa5k-114/high_quality/11317
# Copied from /Users/jeongahlee/Documents/github folder/CubiGraph5K/cubicasa5k-662/high_quality/743 to ../cubicasa5k-114/high_quality/743
# Copied from /Users/jeongahlee/Documents/github folder/CubiGraph5K/cubicasa5k-662/high_quality_architectural/11410 to ../cubicasa5k-114/high_quality_architectural/11410
# Copied from /Users/jeongahlee/Documents/github folder/CubiGraph5K/cubicasa5k-662/high_quality_architectural/11697 to ../cubicasa5k-114/high_quality_architectural/11697
# Copied from /Users/jeongahlee/Documents/github folder/CubiGraph5K/cubicasa5k-662/high_quality_architectural/709 to ../cubicasa5k-114/high_quality_architectural/709
# Copied from /Users/jeongahlee/Documents/github folder/CubiGraph5K/cubicasa5k-662/high_quality/5858 to ../cubicasa5k-114/high_quality/5858
# Copied from /Users/jeongahlee/Documents/github folder/CubiGraph5K/cubicasa5k-662/high_quality_architectural/8323 to ../cubicasa5k-114/high_quality_architectural/8323
# Copied from /Users/jeongahlee/Documents/github folder/CubiGraph5K/cubicasa5k-662/high_quality/107 to ../cubicasa5k-114/high_quality/107
# Copied from /Users/jeongahlee/Documents/github folder/CubiGraph5K/cubicasa5k-662/high_quality_architectural/20113 to ../cubicasa5k-114/high_quality_architectural/20113
# Copied from /Users/jeongahlee/Documents/github folder/CubiGraph5K/cubicasa5k-662/high_quality_architectural/11001 to ../cubicasa5k-114/high_quality_architectural/11001
# Copied from /Users/jeongahlee/Documents/github folder/CubiGraph5K/cubicasa5k-662/high_quality/9857 to ../cubicasa5k-114/high_quality/9857
# Copied from /Users/jeongahlee/Documents/github folder/CubiGraph5K/cubicasa5k-662/high_quality_architectural/9333 to ../cubicasa5k-114/high_quality_architectural/9333
# Copied from /Users/jeongahlee/Documents/github folder/CubiGraph5K/cubicasa5k-662/high_quality_architectural/14293 to ../cubicasa5k-114/high_quality_architectural/14293
# Copied from /Users/jeongahlee/Documents/github folder/CubiGraph5K/cubicasa5k-662/high_quality_architectural/12179 to ../cubicasa5k-114/high_quality_architectural/12179
# Copied from /Users/jeongahlee/Documents/github folder/CubiGraph5K/cubicasa5k-662/high_quality_architectural/10271 to ../cubicasa5k-114/high_quality_architectural/10271
# Copied from /Users/jeongahlee/Documents/github folder/CubiGraph5K/cubicasa5k-662/high_quality_architectural/11699 to ../cubicasa5k-114/high_quality_architectural/11699
# Copied from /Users/jeongahlee/Documents/github folder/CubiGraph5K/cubicasa5k-662/high_quality/9920 to ../cubicasa5k-114/high_quality/9920
# Copied from /Users/jeongahlee/Documents/github folder/CubiGraph5K/cubicasa5k-662/high_quality_architectural/10714 to ../cubicasa5k-114/high_quality_architectural/10714
# Copied from /Users/jeongahlee/Documents/github folder/CubiGraph5K/cubicasa5k-662/high_quality_architectural/8321 to ../cubicasa5k-114/high_quality_architectural/8321
# Copied from /Users/jeongahlee/Documents/github folder/CubiGraph5K/cubicasa5k-662/high_quality/8530 to ../cubicasa5k-114/high_quality/8530
# Copied from /Users/jeongahlee/Documents/github folder/CubiGraph5K/cubicasa5k-662/high_quality_architectural/1814 to ../cubicasa5k-114/high_quality_architectural/1814
# Copied from /Users/jeongahlee/Documents/github folder/CubiGraph5K/cubicasa5k-662/high_quality/6211 to ../cubicasa5k-114/high_quality/6211
# Copied from /Users/jeongahlee/Documents/github folder/CubiGraph5K/cubicasa5k-662/high_quality_architectural/12967 to ../cubicasa5k-114/high_quality_architectural/12967
# Copied from /Users/jeongahlee/Documents/github folder/CubiGraph5K/cubicasa5k-662/high_quality_architectural/6013 to ../cubicasa5k-114/high_quality_architectural/6013
# Copied from /Users/jeongahlee/Documents/github folder/CubiGraph5K/cubicasa5k-662/high_quality/9775 to ../cubicasa5k-114/high_quality/9775
# Copied from /Users/jeongahlee/Documents/github folder/CubiGraph5K/cubicasa5k-662/high_quality_architectural/11000 to ../cubicasa5k-114/high_quality_architectural/11000
# Copied from /Users/jeongahlee/Documents/github folder/CubiGraph5K/cubicasa5k-662/high_quality/11296 to ../cubicasa5k-114/high_quality/11296
# Copied from /Users/jeongahlee/Documents/github folder/CubiGraph5K/cubicasa5k-662/high_quality_architectural/5808 to ../cubicasa5k-114/high_quality_architectural/5808
# Copied from /Users/jeongahlee/Documents/github folder/CubiGraph5K/cubicasa5k-662/high_quality_architectural/10649 to ../cubicasa5k-114/high_quality_architectural/10649
# Copied from /Users/jeongahlee/Documents/github folder/CubiGraph5K/cubicasa5k-662/high_quality/10458 to ../cubicasa5k-114/high_quality/10458
# Copied from /Users/jeongahlee/Documents/github folder/CubiGraph5K/cubicasa5k-662/high_quality_architectural/5974 to ../cubicasa5k-114/high_quality_architectural/5974
# Copied from /Users/jeongahlee/Documents/github folder/CubiGraph5K/cubicasa5k-662/high_quality_architectural/6037 to ../cubicasa5k-114/high_quality_architectural/6037
# Copied from /Users/jeongahlee/Documents/github folder/CubiGraph5K/cubicasa5k-662/high_quality_architectural/8416 to ../cubicasa5k-114/high_quality_architectural/8416
# Copied from /Users/jeongahlee/Documents/github folder/CubiGraph5K/cubicasa5k-662/high_quality/9480 to ../cubicasa5k-114/high_quality/9480
# Copied from /Users/jeongahlee/Documents/github folder/CubiGraph5K/cubicasa5k-662/high_quality_architectural/9351 to ../cubicasa5k-114/high_quality_architectural/9351
# Copied from /Users/jeongahlee/Documents/github folder/CubiGraph5K/cubicasa5k-662/high_quality_architectural/5044 to ../cubicasa5k-114/high_quality_architectural/5044
# Copied from /Users/jeongahlee/Documents/github folder/CubiGraph5K/cubicasa5k-662/high_quality_architectural/14326 to ../cubicasa5k-114/high_quality_architectural/14326
# Copied from /Users/jeongahlee/Documents/github folder/CubiGraph5K/cubicasa5k-662/high_quality_architectural/7089 to ../cubicasa5k-114/high_quality_architectural/7089
# Copied from /Users/jeongahlee/Documents/github folder/CubiGraph5K/cubicasa5k-662/high_quality_architectural/12860 to ../cubicasa5k-114/high_quality_architectural/12860
# Copied from /Users/jeongahlee/Documents/github folder/CubiGraph5K/cubicasa5k-662/high_quality_architectural/9154 to ../cubicasa5k-114/high_quality_architectural/9154
# Copied from /Users/jeongahlee/Documents/github folder/CubiGraph5K/cubicasa5k-662/high_quality/6180 to ../cubicasa5k-114/high_quality/6180
# Copied from /Users/jeongahlee/Documents/github folder/CubiGraph5K/cubicasa5k-662/high_quality_architectural/585 to ../cubicasa5k-114/high_quality_architectural/585
# Copied from /Users/jeongahlee/Documents/github folder/CubiGraph5K/cubicasa5k-662/high_quality/13727 to ../cubicasa5k-114/high_quality/13727
# Copied from /Users/jeongahlee/Documents/github folder/CubiGraph5K/cubicasa5k-662/colorful/13254 to ../cubicasa5k-114/colorful/13254
# Copied from /Users/jeongahlee/Documents/github folder/CubiGraph5K/cubicasa5k-662/colorful/1794 to ../cubicasa5k-114/colorful/1794
# Copied from /Users/jeongahlee/Documents/github folder/CubiGraph5K/cubicasa5k-662/high_quality_architectural/7639 to ../cubicasa5k-114/high_quality_architectural/7639
# Copied from /Users/jeongahlee/Documents/github folder/CubiGraph5K/cubicasa5k-662/colorful/13138 to ../cubicasa5k-114/colorful/13138
# Copied from /Users/jeongahlee/Documents/github folder/CubiGraph5K/cubicasa5k-662/high_quality/6342 to ../cubicasa5k-114/high_quality/6342
# Copied from /Users/jeongahlee/Documents/github folder/CubiGraph5K/cubicasa5k-662/high_quality/3817 to ../cubicasa5k-114/high_quality/3817
# Copied from /Users/jeongahlee/Documents/github folder/CubiGraph5K/cubicasa5k-662/high_quality_architectural/20026 to ../cubicasa5k-114/high_quality_architectural/20026
# Copied from /Users/jeongahlee/Documents/github folder/CubiGraph5K/cubicasa5k-662/high_quality_architectural/14197 to ../cubicasa5k-114/high_quality_architectural/14197
# Copied from /Users/jeongahlee/Documents/github folder/CubiGraph5K/cubicasa5k-662/high_quality_architectural/13071 to ../cubicasa5k-114/high_quality_architectural/13071
# Copied from /Users/jeongahlee/Documents/github folder/CubiGraph5K/cubicasa5k-662/high_quality_architectural/7666 to ../cubicasa5k-114/high_quality_architectural/7666
# Copied from /Users/jeongahlee/Documents/github folder/CubiGraph5K/cubicasa5k-662/high_quality_architectural/98 to ../cubicasa5k-114/high_quality_architectural/98
# Copied from /Users/jeongahlee/Documents/github folder/CubiGraph5K/cubicasa5k-662/high_quality_architectural/12534 to ../cubicasa5k-114/high_quality_architectural/12534
# Copied from /Users/jeongahlee/Documents/github folder/CubiGraph5K/cubicasa5k-662/high_quality_architectural/709 to ../cubicasa5k-114/high_quality_architectural/709
# Copied from /Users/jeongahlee/Documents/github folder/CubiGraph5K/cubicasa5k-662/high_quality_architectural/12042 to ../cubicasa5k-114/high_quality_architectural/12042
#
# ✅ 총 114개의 폴더가 '../cubicasa5k-114'에 복사 완료되었습니다.
